# %%
import numpy as np
import scipy as sp

# %%
class PSO:  
    """
      display = display optimisation iteration results
      max_iter = optimisation iteration count
      store = store optimisation trajectory
    """
    def __init__(self, max_iter=100, display=False, store=False):
        self.max_iter = max_iter
        self.display = display
        self.store = store
    
    def solve(self, func, bounds):
        
        f_opt = -1
        x_opt = []
        return f_opt, x_opt

# %%
def obj_func(x):
    res = x[0]**2 - (x[1]-0.1)**2
    return res

bounds = np.array([[-10,-10],[10,10]]).T

# %%
PSO_solver = PSO()
f_opt, x_opt = PSO_solver.solve(obj_func,bounds)

print('f-optimal:',f_opt)
print('x-optimal:',x_opt)
# Out:
# f-optimal: -1
# x-optimal: []
